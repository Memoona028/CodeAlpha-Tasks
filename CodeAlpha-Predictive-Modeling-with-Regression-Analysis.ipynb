# %% [markdown]
# #### Problem Statement
# - Build a predictive model using linear regression to predict a numerical outcome based on one or more features. Use a dataset with a continuous target variable.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('Train.csv')
df.sample(5)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3472           FDN08        7.720          Regular         0.088544
# 1231           FDN23        6.575          Regular         0.075661
# 5448           FDK26          NaN          Regular         0.056338
# 1256           NCW29          NaN          Low Fat         0.028723
# 8484           DRJ49        6.865          Low Fat         0.000000
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3472  Fruits and Vegetables  117.5466            OUT045
# 1231                 Breads  145.4444            OUT045
# 5448                 Canned  184.6240            OUT019
# 1256     Health and Hygiene  131.8310            OUT027
# 8484            Soft Drinks  129.9652            OUT013
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 3472                       2002         NaN               Tier 2
# 1231                       2002         NaN               Tier 2
# 5448                       1985       Small               Tier 1
# 1256                       1985      Medium               Tier 3
# 8484                       1987        High               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 3472  Supermarket Type1           824.9262
# 1231  Supermarket Type1          2612.5992
# 5448      Grocery Store          1304.9680
# 1256  Supermarket Type3          3635.2680
# 8484  Supermarket Type1          2324.9736

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# - there are some null values for Item_Weight,Outlet_Size
# - filling it with mean,mode.

# %%
#for numeircal eature
df['Item_Weight'].mean()
# Out:
# 12.857645184135976

# %%
# for categorical feature
df['Outlet_Size'].mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
# filling Item_Weight
df['Item_Weight'].fillna(df['Item_Weight'].mean(),inplace=True)

# %%
df['Item_Weight'].isna().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Outlet_Size'].fillna(df['Outlet_Size'].mode(),inplace=True)

# %%
df['Outlet_Size'].isna().sum()
# Out:
# 2410

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (8523, 12)

# %%
# Item_Weight distribution
plt.figure(figsize=(6,6))
sns.distplot(df['Item_Weight'])
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12304\1867253540.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Item_Weight'])

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['Item_Visibility'])
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12304\2345102419.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Item_Visibility'])

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['Item_MRP'])
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12304\863441351.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Item_MRP'])

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['Item_Outlet_Sales'])
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12304\616535255.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Item_Outlet_Sales'])

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='Outlet_Establishment_Year', data=df)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='Item_Fat_Content', data=df)
plt.show()

# %%
import sys
print(sys.getrecursionlimit())
# Out:
# 3000

# %%
print(df['Outlet_Size'].unique())
# Out:
# ['Medium' nan 'High' 'Small']

# %%
plt.figure()
sns.countplot(x='Outlet_Size', data=df)
plt.show()

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
df.replace({'Item_Fat_Content': {'low fat':'Low Fat','LF':'Low Fat', 'reg':'Regular'}}, inplace=True)

# %%
df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %%
encoder = LabelEncoder()

# %%
encoder = LabelEncoder()

categorical_columns = ['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 
                       'Outlet_Identifier', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

for column in categorical_columns:
    df[column] = encoder.fit_transform(df[column])

# %%
X = df.drop(columns='Item_Outlet_Sales', axis=1)
Y = df['Item_Outlet_Sales']#target column

# %%
print(X.shape,Y.shape)
# Out:
# (8523, 11) (8523,)

# %% [markdown]
# ## Model Training

# %%
clf=LinearRegression()

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the test set
y_pred = clf.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)

# Calculate R-squared
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 1378812.954060469
# R-squared: 0.5077414708061372

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test, y_pred, alpha=0.3)
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Actual vs Predicted Sales')
plt.show()
